# %% [markdown]
# Name : Md Mynuddin\
# Roll : ASH1825007M\
# Assignment : Code Size And Design Size\
# But here is only code size , I also provide design size with SRS Measurement.I try my best.

# %% [markdown]
# ## Code Size
#
#     Total size, LOC (Effective Line)= NCLOC(Non Commented Line) + CLOC(Comented Line)
#     Measure Technique: Automated Program
#     Language : Java

# %%
import os
import pandas as pd

Files = os.listdir('picture_puzzle_project')
Files
# Out:
# ['Pic_Launcher.java',
#  'pause.jpg',
#  'StartPuzzle.java',
#  'Home-512.png',
#  'Cell.java',
#  'puz.png',
#  'add-file.png',
#  'select-icon-png-24.jpg',
#  'Puzzle.java',
#  'back.png',
#  'replay.jpg',
#  'Figure.java',
#  'ImageLoader.java',
#  'select-icon.jpg',
#  'play-button.png',
#  'ImageResizer.java',
#  'home-513.png',
#  'Board.java']

# %%
JavaFiles = []
for files in Files:
    if files.endswith(".java"):
        JavaFiles.append(files)
        
        
JavaFiles
# Out:
# ['Pic_Launcher.java',
#  'StartPuzzle.java',
#  'Cell.java',
#  'Puzzle.java',
#  'Figure.java',
#  'ImageLoader.java',
#  'ImageResizer.java',
#  'Board.java']

# %%
len(JavaFiles)
# Out:
# 8

# %%
FinalResult = []

for f in range(len(JavaFiles)):

    file = open(JavaFiles[f], "r")

    CLine = 0
    NCLine = 0
    BLine = 0
    TLC = 0

    Filelines = []

    for line in file:
      TLC += 1
      Filelines.append(line)

    for i in range(TLC):
      if '//' in Filelines[i]:
        CLine += 1
      if '/*' in Filelines[i]:
        while '*' in Filelines[i]:
          CLine += 1
          i += 1
      if Filelines[i].strip() == "":
        BLine += 1


    NCLine = TLC - CLine - BLine
    file.close()

    print("\nFor Java File" , JavaFiles[f])
    print("---------------------------------")

    print("Total number of Line in code: ",TLC)
    print("Number of commented line of code:", CLine)
    print("Number of blank line of code:", BLine)
    print("Number of non-commented line of code", NCLine)
    
    Summary = {
        "JavaFiles":JavaFiles[f],
        "TLC":TLC,
        "CLine":CLine,
        "NCLine" :NCLine,
        "BLine":BLine
       }
    print(Summary)
    
    FinalResult.append(Summary)
# Out:
# For Java File Pic_Launcher.java
# ---------------------------------
# Total number of Line in code:  26
# Number of commented line of code: 6
# Number of blank line of code: 6
# Number of non-commented line of code 14
# {'JavaFiles': 'Pic_Launcher.java', 'TLC': 26, 'CLine': 6, 'NCLine': 14, 'BLine': 6}
#
# For Java File StartPuzzle.java
# ---------------------------------
# Total number of Line in code:  114
# Number of commented line of code: 8
# Number of blank line of code: 18
# Number of non-commented line of code 88
# {'JavaFiles': 'StartPuzzle.java', 'TLC': 114, 'CLine': 8, 'NCLine': 88, 'BLine': 18}
#
# For Java File Cell.java
# ---------------------------------
# Total number of Line in code:  32
# Number of commented line of code: 1
# Number of blank line of code: 4
# Number of non-commented line of code 27
# {'JavaFiles': 'Cell.java', 'TLC': 32, 'CLine': 1, 'NCLine': 27, 'BLine': 4}
#
# For Java File Puzzle.java
# ---------------------------------
# Total number of Line in code:  241
# Number of commented line of code: 37
# Number of blank line of code: 38
# Number of non-commented line of code 166
# {'JavaFiles': 'Puzzle.java', 'TLC': 241, 'CLine': 37, 'NCLine': 166, 'BLine': 38}
#
# For Java File Figure.java
# ---------------------------------
# Total number of Line in code:  134
# Number of commented line of code: 13
# Number of blank line of code: 22
# Number of non-commented line of code 99
# {'JavaFiles': 'Figure.java', 'TLC': 134, 'CLine': 13, 'NCLine': 99, 'BLine': 22}
#
# For Java File ImageLoader.java
# ---------------------------------
# Total number of Line in code:  25
# Number of commented line of code: 5
# Number of blank line of code: 6
# Number of non-commented line of code 14
# {'JavaFiles': 'ImageLoader.java', 'TLC': 25, 'CLine': 5, 'NCLine': 14, 'BLine': 6}
#
# For Java File ImageResizer.java
# ---------------------------------
# Total number of Line in code:  22
# Number of commented line of code: 5
# Number of blank line of code: 3
# Number of non-commented line of code 14
# {'JavaFiles': 'ImageResizer.java', 'TLC': 22, 'CLine': 5, 'NCLine': 14, 'BLine': 3}
#
# For Java File Board.java
# ---------------------------------
# Total number of Line in code:  98
# Number of commented line of code: 16
# Number of blank line of code: 14
# Number of non-commented line of code 68
# {'JavaFiles': 'Board.java', 'TLC': 98, 'CLine': 16, 'NCLine': 68, 'BLine': 14}

# %%
FinalResult
# Out:
# [{'JavaFiles': 'Pic_Launcher.java',
#   'TLC': 26,
#   'CLine': 6,
#   'NCLine': 14,
#   'BLine': 6},
#  {'JavaFiles': 'StartPuzzle.java',
#   'TLC': 114,
#   'CLine': 8,
#   'NCLine': 88,
#   'BLine': 18},
#  {'JavaFiles': 'Cell.java', 'TLC': 32, 'CLine': 1, 'NCLine': 27, 'BLine': 4},
#  {'JavaFiles': 'Puzzle.java',
#   'TLC': 241,
#   'CLine': 37,
#   'NCLine': 166,
#   'BLine': 38},
#  {'JavaFiles': 'Figure.java',
#   'TLC': 134,
#   'CLine': 13,
#   'NCLine': 99,
#   'BLine': 22},
#  {'JavaFiles': 'ImageLoader.java',
#   'TLC': 25,
#   'CLine': 5,
#   'NCLine': 14,
#   'BLine': 6},
#  {'JavaFiles': 'ImageResizer.java',
#   'TLC': 22,
#   'CLine': 5,
#   'NCLine': 14,
#   'BLine': 3},
#  {'JavaFiles': 'Board.java',
#   'TLC': 98,
#   'CLine': 16,
#   'NCLine': 68,
#   'BLine': 14}]

# %%
import matplotlib.pyplot as plt

for i in FinalResult:
    x=list(i.values())
    
    fig = plt.figure()
    ax = fig.add_axes([0,0,1,1])
#     ax.axis('equal')
    Measure = ['TLC = Total Line Of Code', 'CLine = Commented Line', 'NCLine = Non Commented Line', 'BLine = Blank Line']

    Data = x[1:]
    ax.pie(Data, labels = Measure ,autopct='%1.2f%%')
    plt.show()
    
    print("-----------------------",x[0],"---------------------------")
# Out:
# ----------------------- Pic_Launcher.java ---------------------------
# ----------------------- StartPuzzle.java ---------------------------
# ----------------------- Cell.java ---------------------------
# ----------------------- Puzzle.java ---------------------------
# ----------------------- Figure.java ---------------------------
# ----------------------- ImageLoader.java ---------------------------
# ----------------------- ImageResizer.java ---------------------------
# ----------------------- Board.java ---------------------------
